# %%
import matplotlib.pyplot as plt
import numpy as np
import random 

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [22 38 39 52 20 11 19 27 57 35 56 18 13 53 48 37 58 41 47 14 33 52 50 20
#  48 11 15 17 59 48 30 48 23 58 37 50 20 36 29 34 58 22 22 51 53 47 52 50
#  58 57]

# %%
no=[22,38,39,52,20,11,19,27,57,35,56,18,13,53,48,37,58,41,47,14,33,52,50,20,
 48,11,15,17,59,48,30,48,23,58,37,50,20,36,29,34,58,22,22,51,53,47,52,50,
 58,57]

plt.hist(no,color="y",edgecolor="r",label="python")
plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No")
plt.legend()
plt.show()
